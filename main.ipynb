# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image
import hashlib

# %%
# train random 5 images from each class
train_dir = "original_image/train"
train_dir_classes = os.listdir(train_dir)

for classes in train_dir_classes:
    class_path = os.path.join(train_dir, classes)

    img_name = os.listdir(class_path)


    random5 = random.sample(img_name, 5)

    plt.figure(figsize=(15,3))
    for index, img in enumerate(random5):
        img_complete_path = os.path.join(class_path, img)
        
        img = Image.open(img_complete_path)

        plt.subplot(1, 5, index+1)
        plt.imshow(img)
        plt.title(classes)
        plt.axis('off')
    plt.show()

# %%
val_dir = "original_image/test"
val_dir_classes = os.listdir(val_dir)

for classes in val_dir_classes:
    class_path = os.path.join(val_dir, classes)

    img_name = os.listdir(class_path)


    random5 = random.sample(img_name, 5)

    plt.figure(figsize=(15,3))
    for index, img in enumerate(random5):
        img_complete_path = os.path.join(class_path, img)
        
        img = Image.open(img_complete_path)

        plt.subplot(1, 5, index+1)
        plt.imshow(img)
        plt.title(classes)
        plt.axis('off')
    plt.show()

# %%
train_dir = "original_image/train"
train_dir_classes = os.listdir(train_dir)

for classes in train_dir_classes:
    
    class_path = os.path.join(train_dir, classes)

    img_name = os.listdir(class_path)
    print(f" Number of images in {classes} class: {len(img_name)}")
# Out:
#  Number of images in angry class: 3849
#  Number of images in disgust class: 381
#  Number of images in fear class: 3904
#  Number of images in happy class: 7086
#  Number of images in neutral class: 4868
#  Number of images in sad class: 4716
#  Number of images in surprise class: 2669

# %%
val_dir = "original_image/test"
val_dir_classes = os.listdir(val_dir)

for classes in val_dir_classes:
    
    class_path = os.path.join(val_dir, classes)

    img_name = os.listdir(class_path)
    print(f" Number of images in {classes} class: {len(img_name)}")
# Out:
#  Number of images in angry class: 946
#  Number of images in disgust class: 109
#  Number of images in fear class: 1013
#  Number of images in happy class: 1767
#  Number of images in neutral class: 1225
#  Number of images in sad class: 1240
#  Number of images in surprise class: 792

# %%
def hasher_images(file_path):
    hasher = hashlib.md5()
    with open(file_path, 'rb') as f:
        img = f.read()
        hasher.update(img)
    return hasher.hexdigest()

duplicates = []
images = {}

for root, dirs, file in os.walk("original_image/train"):
    for file in file:
        img_path = os.path.join(root, file)
        hash_value = hasher_images(img_path)

        if hash_value in images:
            duplicates.append((hash_value, img_path))
        else:
            images[hash_value] = img_path

# %%
print(len(duplicates))
# Out:
# 0

# %%
if len(duplicates) >= 5:
    random5 = random.sample(duplicates, 5)
else:
    random5 = duplicates

for hash_value, img_path in random5:
    duplicate_img_path = img_path
    original_img_path = images[hash_value]

    plt.figure(figsize=(8, 3))

    plt.subplot(1, 2, 1)
    duplicate_img = Image.open(duplicate_img_path)
    plt.imshow(duplicate_img)
    plt.title("Duplicate")

    plt.subplot(1, 2, 2)
    original_img = Image.open(original_img_path)
    plt.imshow(original_img)
    plt.title("Original")

    plt.show()

# %%
def hasher_images(file_path):
    hasher = hashlib.md5()
    with open(file_path, 'rb') as f:
        img = f.read()
        hasher.update(img)
    return hasher.hexdigest()

duplicates = []
images = {}

for root, dirs, file in os.walk("original_image/train"):
    for file in file:
        img_path = os.path.join(root, file)
        hash_value = hasher_images(img_path)

        if hash_value in images:
            duplicates.append((hash_value, img_path))
        else:
            images[hash_value] = img_path

# %%
duplicates_different_classes = 0

for hash_value, img_path in duplicates:
    duplicate_img_path = img_path
    original_img_path = images[hash_value]

    duplicate_img_class = os.path.split(duplicate_img_path)[0].split("/")[-1]
    original_img_class = os.path.split(original_img_path)[0].split("/")[-1]

    if duplicate_img_class != original_img_class:
        duplicates_different_classes += 1
        print("original_emotion :", original_img_class)
        print("duplicate_emotion:", duplicate_img_class)

print(duplicates_different_classes)
# Out:
# 0

# %%
for hash_value, img_path in duplicates:
    duplicate_img_path = img_path

    if os.path.exists(duplicate_img_path):
        try:
            os.remove(duplicate_img_path)
        except Exception as e:
            print("Error while removing", e)

print("duplicate images are removed")
# Out:
# duplicate images are removed

# %%
def hasher_images(file_path):
    hasher = hashlib.md5()
    with open(file_path, 'rb') as f:
        img = f.read()
        hasher.update(img)
    return hasher.hexdigest()

duplicates = []
images = {}

for root, dirs, file in os.walk("original_image/train"):
    for file in file:
        img_path = os.path.join(root, file)
        hash_value = hasher_images(img_path)

        if hash_value in images:
            duplicates.append((hash_value, img_path))
        else:
            images[hash_value] = img_path

               
print(len(duplicates))
# Out:
# 0

# %%
def hasher_images(file_path):
    hasher = hashlib.md5()
    with open(file_path, 'rb') as f:
        img = f.read()
        hasher.update(img)
    return hasher.hexdigest()

duplicates = []
images = {}

for root, dirs, file in os.walk("original_image/test"):
    for file in file:
        img_path = os.path.join(root, file)
        hash_value = hasher_images(img_path)

        if hash_value in images:
            duplicates.append((hash_value, img_path))
        else:
            images[hash_value] = img_path

               
print(len(duplicates))
# Out:
# 0

# %%
duplicates_different_classes = 0

for hash_value, img_path in duplicates:
    duplicate_img_path = img_path
    original_img_path = images[hash_value]

    duplicate_img_class = os.path.split(duplicate_img_path)[0].split("/")[-1]
    original_img_class = os.path.split(original_img_path)[0].split("/")[-1]

    if duplicate_img_class != original_img_class:
        duplicates_different_classes += 1
        print("original_emotion :", original_img_class)
        print("duplicate_emotion:", duplicate_img_class)

print(duplicates_different_classes)
# Out:
# 0

# %%
for hash_value, img_path in duplicates:
    duplicate_img_path = img_path

    if os.path.exists(duplicate_img_path):
        try:
            os.remove(duplicate_img_path)
        except Exception as e:
            print("Error while removing", e)

print("duplicate images are removed")
# Out:
# duplicate images are removed

# %%
def hasher_images(file_path):
    hasher = hashlib.md5()
    with open(file_path, 'rb') as f:
        img = f.read()
        hasher.update(img)
    return hasher.hexdigest()

duplicates = []
images = {}

for root, dirs, file in os.walk("original_image/test"):
    for file in file:
        img_path = os.path.join(root, file)
        hash_value = hasher_images(img_path)

        if hash_value in images:
            duplicates.append((hash_value, img_path))
        else:
            images[hash_value] = img_path

               
print(len(duplicates))
# Out:
# 0

# %%
# finding corrupt images

for root, dirs, file in os.walk("original_image/train"):
    for file in file:
        img_path = os.path.join(root, file)

        try:
            with open(img_path, 'rb') as img:
                image = Image.open(img_path)
                image.verify()
        except Exception as e:
            print("Error", e)
            print("img_path")

print("corrupt images checked")
# Out:
# corrupt images checked

# %%
for root, dirs, file in os.walk("original_image/train"):
    unique_files = []
    for file in file:
        img_path = os.path.join(root, file)

        img_path_splitted = os.path.split(img_path)[-1].split(".")[-1]
        if img_path_splitted not in unique_files:
            unique_files.append(img_path_splitted)

    print(root)
    print(unique_files)
    print()
# Out:
# original_image/train
# []
#
# original_image/train\angry
# ['jpg']
#
# original_image/train\disgust
# ['jpg']
#
# original_image/train\fear
# ['jpg']
#
# original_image/train\happy
# ['jpg']
#
# original_image/train\neutral
# ['jpg']
#
# original_image/train\sad
# ['jpg']
#
# original_image/train\surprise
# ['jpg']

# %%
for root, dirs, file in os.walk("original_image/test"):
    unique_files = []
    for file in file:
        img_path = os.path.join(root, file)

        img_path_splitted = os.path.split(img_path)[-1].split(".")[-1]
        if img_path_splitted not in unique_files:
            unique_files.append(img_path_splitted)

    print(root)
    print(unique_files)
    print()
# Out:
# original_image/test
# []
#
# original_image/test\angry
# ['jpg']
#
# original_image/test\disgust
# ['jpg']
#
# original_image/test\fear
# ['jpg']
#
# original_image/test\happy
# ['jpg']
#
# original_image/test\neutral
# ['jpg']
#
# original_image/test\sad
# ['jpg']
#
# original_image/test\surprise
# ['jpg']

# %%
def check_image_size(folder_path):
    sizes = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            image_path = os.path.join(root, file)
            with Image.open(image_path) as img:
                image_size = img.size
            if image_size not in sizes:
                sizes.append(image_size)

        for size in sizes:
            print(f"unique image size in {root}:{size}")
        print("-"*80)

folder_path = "original_image"
check_image_size(folder_path)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# unique image size in original_image\test\angry:(48, 48)
# --------------------------------------------------------------------------------
# unique image size in original_image\test\disgust:(48, 48)
# --------------------------------------------------------------------------------
# unique image size in original_image\test\fear:(48, 48)
# --------------------------------------------------------------------------------
# unique image size in original_image\test\happy:(48, 48)
# --------------------------------------------------------------------------------
# unique image size in original_image\test\neutral:(48, 48)
# --------------------------------------------------------------------------------
# unique image size in original_image\test\sad:(48, 48)
# ...

# %%
for root, dirs, file in os.walk("original_image/train"):
    unique_image_file_size = []
    for file in file:
        img_path = os.path.join(root, file)

        try:
            file_size = os.path.getsize(img_path)/1024
            kb_file_size = round(file_size, 2)
            unique_image_file_size.append(kb_file_size)
            
        except Exception as e:
            print("Error", e)
            

print(unique_image_file_size)
# Out:
